# %%
## we need to get data for each of the users
# shoudl they be polictical data?, most preferably so

import pandas as pd

df = pd.read_csv('/home/sunny/Desktop/us-presidential-tweet-id-2020-09-30-16.csv', nrows=5)
df
# Out:
#    coordinates                      created_at       hashtags  \
# 0          NaN  Wed Sep 30 15:59:55 +0000 2020            NaN
# 1          NaN  Wed Sep 30 15:59:55 +0000 2020  Biden COVID19
# 2          NaN  Wed Sep 30 15:59:55 +0000 2020            NaN
# 3          NaN  Wed Sep 30 15:59:55 +0000 2020            NaN
# 4          NaN  Wed Sep 30 15:59:55 +0000 2020            NaN
#
#                                                media  \
# 0                                                NaN
# 1                                                NaN
# 2  https://twitter.com/SmdSzn/status/131112610565...
# 3                                                NaN
# 4                                                NaN
#
#                                                 urls  favorite_count  \
# 0                                                NaN               0
# 1                                                NaN               0
# ...

# %%
pd.set_option('display.max_colwidth', 100000)

df.columns
# Out:
# Index(['coordinates', 'created_at', 'hashtags', 'media', 'urls',
#        'favorite_count', 'id', 'in_reply_to_screen_name',
#        'in_reply_to_status_id', 'in_reply_to_user_id', 'lang', 'place',
#        'possibly_sensitive', 'retweet_count', 'retweet_id',
#        'retweet_screen_name', 'source', 'text', 'tweet_url', 'user_created_at',
#        'user_screen_name', 'user_default_profile_image', 'user_description',
#        'user_favourites_count', 'user_followers_count', 'user_friends_count',
#        'user_listed_count', 'user_location', 'user_name', 'user_screen_name.1',
#        'user_statuses_count', 'user_time_zone', 'user_urls', 'user_verified'],
#       dtype='object')

# %%
df1 = df[['user_name', 'coordinates', 'created_at', 'hashtags', 'id', 'text']]
df1
# Out:
#                                 user_name  coordinates  \
# 0                     PerfectStormRider!7          NaN
# 1                          Grace Granlund          NaN
# 2                                  mvpito          NaN
# 3  Hästronaut (((🐎))) Ĉevalo de l’ Steloj          NaN
# 4                     🇺🇲 Samuel Melton 🇺🇲          NaN
#
#                        created_at       hashtags                   id  \
# 0  Wed Sep 30 15:59:55 +0000 2020            NaN  1311334973065043968
# 1  Wed Sep 30 15:59:55 +0000 2020  Biden COVID19  1311334973434073088
# 2  Wed Sep 30 15:59:55 +0000 2020            NaN  1311334973098602496
# 3  Wed Sep 30 15:59:55 +0000 2020            NaN  1311334973417324546
# 4  Wed Sep 30 15:59:55 +0000 2020            NaN  1311334973367111680
#
#                                                                                                                                              text
# ...
